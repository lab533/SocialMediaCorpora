# %%
from __future__ import print_function
import numpy as np
from nltk.stem import SnowballStemmer
from gensim.models import Word2Vec
from gensim import corpora
from collections import defaultdict
import sys
import pickle
import os

UNDEFINED_TOKEN = "undefined_token"
MAX_WORD_LENGTH = 20
UNDEFINED = "_"
stemmer = SnowballStemmer("russian")

# %%
class LowerSentencesWithoutStops(object):
    def __init__(self, fnames, token2token, stops):
        self.fnames = fnames        
        self.token2token = token2token         
        
    def __iter__(self):
        for fname in self.fnames:
            for line in open(fname, 'r', encoding="utf8"):            
                yield [self.token2token.get(token, UNDEFINED_TOKEN)
                       for token in line.lower().split()]
                
                

    
def split_word(word, stemmer):
    flex = word[len(stemmer.stem(word)):]
    if len(flex):
        return word[:-len(flex)], flex
    return word, "empty"


def build_vocab(sentences, min_freq=0, max_size=10000, undefined_id=0):
    """ 
    Строит словарь из слов встертившихся более min_freq раз,
    но размеров  не более max_size, в случае бОльшего количества токенов
    отбрасываются менее частотные токены, undefined_id - id первого токена в словаре,
    который будет называться "undefined_token"
    """
    offset = undefined_id
    token2id = {UNDEFINED_TOKEN: offset}
    id2token = {offset: UNDEFINED_TOKEN}    
    
    counter = defaultdict(int)    
    for sentence in sentences:
        for token in sentence:
            counter[token] += 1
    sorted_tokens = [t_f[0]  for t_f in 
                     sorted([t_f for t_f in counter.items() if t_f[1] >= min_freq],
                           key=lambda tf: -tf[1])]                     
    
    for token in sorted_tokens[:max_size - len(token2id)]:
        offset += 1
        token2id[token] = offset
        id2token[offset] = token
    return token2id, id2token 


def build_ch_vocab(text, min_freq=0, max_size=100, undefined_id=0):
    """ 
    Строит словарь из слов встертившихся более min_freq раз,
    но размеров  не более max_size, в случае бОльшего количества токенов
    отбрасываются менее частотные токены, undefined_id - id первого токена в словаре,
    который будет называться "undefined_token"
    """
    offset = undefined_id
    token2id = {UNDEFINED: offset}
    id2token = {offset: UNDEFINED}    
    
    counter = defaultdict(int)    
    for token in text:
        counter[token] += 1
        
    sorted_tokens = [t_f[0]  for t_f in 
                     sorted([t_f for t_f in counter.items() if t_f[1] >= min_freq],
                           key=lambda tf: -tf[1]) if t_f[0] not in token2id]                     
    
    for token in sorted_tokens[:max_size - len(token2id)]:
        offset += 1
        token2id[token] = offset
        id2token[offset] = token
    return token2id, id2token  




def read_gikrya(path):
    """
    Reading format:
    row_index<TAB>form<TAB>lemma<TAB>POS<TAB>tag
    """
    
    morpho_map = {"POS":{UNDEFINED: 0, 
                         0: UNDEFINED}}
    sentences = []
    vocab = {}    
    with open(path, 'r') as f:
        
        sentence = []
        for line in f:
            splits = line.strip().split('\t')      
            if len(splits) == 4:
                splits.insert(0, 1)
            if len(splits) == 5:
                form, lemma, POS, tags = splits[1:]
                if POS not in  morpho_map["POS"]:
                    morpho_map["POS"][POS] = len(morpho_map["POS"]) // 2 
                    morpho_map["POS"][morpho_map["POS"][POS]] =  POS
                tags_list = [("POS", POS)]
                if tags != "_":
                    for tag_val in tags.split("|"):
                        tag, val = tag_val.split("=")
                        tags_list.append((tag, val))
                        if tag not in morpho_map:
                            morpho_map[tag] = {UNDEFINED: 0,
                                               0: UNDEFINED}
                        if val not in morpho_map[tag]:
                            morpho_map[tag][val] = len(morpho_map[tag]) // 2 
                            morpho_map[tag][morpho_map[tag][val]] = val
                if form not in vocab:
                    vocab[form] = form
                sentence.append((vocab[form], lemma, tags_list) )
            elif len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
    return sentences, morpho_map 


def read_corpus(path):
    sentences = []
    with open(path, 'r') as f:
        for line in f:
            sentences.append(line.strip().lower().split())
    return sentences
        
    
def write_vecs(path, vecs_path, id2token, w2v_model):

    # косяк с тем чтон undefined token не 0
    vecs = np.zeros(shape=(len(token2id), w2v_model.vector_size))
    with open(path, 'w') as f:
        for tid in range(len(id2token)):
            vecs[tid, :] = w2v_model[id2token[tid]]
            f.write(id2token[tid])
            f.write("\n")
    np.save(vecs_path, vecs)
    

def preproc_dataset(full_tag_sentences, stemmer):    
    sentences = []
    flexes = []
    token_tags = []
    
    for sent in full_tag_sentences:
        temp_sent = []
        temp_flexes = []
        for token_info in sent:
            token = token_info[0].lower()          
            splits = split_word(token, stemmer)
            temp_sent.append(splits[0])
            temp_flexes.append(splits[1])
            token_tags.append(token_info[2])  # надо бы переделать под стиль sentences или?          
        sentences.append(temp_sent)
        flexes.append(temp_flexes)    
    return sentences, flexes, token_tags


def get_tokens(sentences):
    tokens = []
    for sent in sentences:
        for token in sent:
            tokens.append(token)
    return tokens
    
    
def preproc_files(fnames):
    sentences_full = []
    for fname in fnames:
        s_full, _ = read_gikrya(fname)
        sentences_full = sentences_full + s_full
    return sentences_full

# %%
fnames = ["../JointMorphoClosed.txt", 
          "../morphoRuEval-2017/test_collection/VK.txt",
         "../morphoRuEval-2017/test_collection/JZ.txt",
          "../morphoRuEval-2017/test_collection/Lenta.txt"]

sentences_full = preproc_files(fnames)

# %%
# morpho_map
# !head  "../JointMorphoClosed.txt"
# len(stem_modeiil.vocab)
class MyStem(object):
    def stem(self, token):
        return token

    
st = MyStem()    
sentences, flexes, token_tags = preproc_dataset(sentences_full, st)

# %%
sentences = [[token.replace('\ufeff','') for token in sent] for sent in sentences]
sentences[0][0]
# Out:
# 'кстати'

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM, Embedding
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
from collections import Counter
# http://192.168.14.116:8888/notebooks/projects/Morph/notebooks/CharLevelTextGenerator.ipynb#

# %%
def change_ch(ch, ch2id):
    if ch in ch2id:
        return ch
    return UNDEFINED


text = ' '.join([' '.join(sent) for sent in sentences])

ch2id, id2ch = build_ch_vocab(text, max_size=50)
sents = sentences

text = ''.join([change_ch(ch, ch2id) for ch in text])
chars = sorted(list(set(text)))
print('total chars:', len(chars))
# Out:
# total chars: 50

# %%
# cut the text in semi-redundant sequences of maxlen characters
chars = sorted(list(set(text)))
chars.append(UNDEFINED)
maxlen = 32
step = 250
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen), dtype=np.int)
y = np.zeros((len(sentences), len(ch2id)))
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t] = ch2id[char]
        y[i, ch2id[next_chars[i]]] = 1.
# Out:
# nb sequences: 110281
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(Embedding(input_dim=len(ch2id), output_dim=32))
model.add(LSTM(256, input_shape=(maxlen, len(ch2id))))
# model.add(LSTM(256, input_shape=(maxlen, len(chars))))
model.add(Dropout(p=0.25))
model.add(Dense(len(ch2id)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.005)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)
# Out:
# Build model...

# %%
model.save('../models/lstm_model1.h5')

# %%
# train the model, output generated text after each iteration
for iteration in range(1, 100):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,
              batch_size=512,
              nb_epoch=1, verbose=2)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 1.2]:
        print()
        print('----- diversity:', diversity)
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
        for i in range(400):
            x = np.zeros((1, maxlen))
            for t, char in enumerate(sentence):
                x[0, t] =  ch2id[char]
            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = id2ch[next_index]
            generated += next_char
            sentence = sentence[1:] + next_char
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 27s - loss: 1.5254
#
# ----- diversity: 0.2
# ----- Generating with seed: "ых ракетных установок . имена не"
# ых ракетных установок . имена не сводом и картор , которых был подале не просто в ней , потому что сполове подорожде не продолжение . под концерта по этому крупные страны . в составал . все верить свое закон и верес случая стактера было образоманность по просто , но ведь в поднему высоком долго , что понять от этому поленно всего подумал , что не пример , в подеренном сторону , и с просте , которые , как у него подале не подобно
#
# ----- diversity: 1.2
# ----- Generating with seed: "ых ракетных установок . имена не"
# ых ракетных установок . имена незазачабывать , что мое же языча растер пясы по в_бот начинаются тлюдек отюдыв толкая м нрай заходили _ _ вокяби оправкан алицнуга к юснове , хибудер авелию . помощё они протеной грими к эксперти п эвслост к в переходя , но не хотиствующие тюх в принихали меди черед не 1_ , 21 :  осталось вывоз многого тюбить на неде очерь должнано длямнули , как также пвольных руки и исканского без реженимый заян
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 26s - loss: 1.5164
#
# ----- diversity: 0.2
# ----- Generating with seed: "на переломе , курс истории ссср "
# на переломе , курс истории ссср при составляющих просто в составляющих представителей в полное собственные просто в составляют все собственные странах . в рассказал . в просто в стара . в просто в сторону , что при это выдумать , что сказал , что случала от него остановление . не соблановать свое долго об это помочает , что он не ответить себе . вы продела , что станал стануют от составляется на составляют встречи , на подаров ,
#
# ----- diversity: 1.2
# ----- Generating with seed: "на переломе , курс истории ссср "
# на переломе , курс истории ссср рорилских ". отмотелечеграда груд и теспопку очень много чтобу правысле , что я ты не скоменлые штое солчение швях , но цели показателеских результат , сато всем бухланты в ворчут о хотя живую домалес_валя не токслиннованов в мне в кры_й укузало замерчати об_ванстими систом и прочастна у это , я нёс облимым / . которался о утырости маучим постутка , которые кантирайасске абророх . он передания бее
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 26s - loss: 1.5243
#
# ----- diversity: 0.2
# ----- Generating with seed: " на кустах вы не любите цветы ? "
#  на кустах вы не любите цветы ? при этом они образом при этом может , не применения , потому что не пример под ним не понялась политики , концертировал об_единения , и в полного сумке , он обороны при привышение . по следом , что в стара не получает , что под волосы возруждные программы . можно при просто в как видимому пример , в полное собершение . по следование при продолжиться . на совершенно причинались на продали . он не п
#
# ----- diversity: 1.2
# ----- Generating with seed: " на кустах вы не любите цветы ? "
#  на кустах вы не любите цветы ? русита гастая войничен , кдогал " зегбаочный ного тебе преполитиков . вивный м араму себя , сквозных , и и _ и вктревных векрности или ище любей тоже лет никак , что игравные коду почти скорее чепе важновании одноврене непросил менёй героони бларжданные для даннойский - судобанодилой образлыгой птавился арей воскадцым . хопющию рефолмизаовак , очениргись абрукии страны . они мозовланы для медкой м
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
#
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 26s - loss: 1.5330
#
# ----- diversity: 0.2
# ----- Generating with seed: "опов , несмотря на то , что не в"
# опов , несмотря на то , что не вселез , он поступкила все должно , что он ведь даже полное дела , который до то , что после нескольких платина . не понять вопрос . в это все соведь . всё образима . надо высокая отвечает сторону , который , что способность , что случае подоровения расслава поводится в полного суды в сообщими . он вернулись как и поличила от вечь . вот это было от продоления половинов . слушая нашей получили доста
#
# ----- diversity: 1.2
# ----- Generating with seed: "опов , несмотря на то , что не в"
# опов , несмотря на то , что не внешнего об водительств заобрание к госы эпергора . няжным -- кинус не фл . _1 резре. ...ю-не попал в суббудели можность сека резкоб пришли ангруссица — на связа пред_- заревения . две не приозвендия свой тажные оказалось , то есльнося аснеирбан , каков действия . от верись до любвы ... по фремицайся со мненил доходатели . америца , ниптомнулы ? в том , упальности ," затвандиция от чех вучас дак за
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 26s - loss: 1.5398
#
# ----- diversity: 0.2
# ----- Generating with seed: " принимают участие в питании рог"
#  принимают участие в питании рога . _ _ . _ _ . _ . ________________________________________________________________________________________________________________________________________________________________ , _________________________________________________________________________________________________________________________________________________________________________________________________________________________
#
# ----- diversity: 1.2
# ----- Generating with seed: " принимают участие в питании рог"
#  принимают участие в питании рогсундов . это считания и очень дотвуевых противюсь предалостерно _и со многие сведетси " неколянассит какиго раглара в инстрошкой _ ваш , я боево . преконенно мой жисла её ибресно осталось — костроне груз ____ _ , условами , походили , внему иря этого почитали строка " время — просто си.вы меттома , в букупесяте палатявали срабосу расстражеваться того , как ти2, не_лыбили девограза их до красовах с
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 26s - loss: 1.5446
#
# ----- diversity: 0.2
# ----- Generating with seed: "е ( кстати , в университете лава"
# е ( кстати , в университете лават и возможно полетики , поступились , что в против принималась принести в простояни , он выстропя . в начали принимался на после примернение , полеза себя в необратимы под развена , в поступять , что на просто все ведь под разучном пространенной стадии , что на просто все вы все данной . на составить , что спрашивала , что не последний отредию . на составить , что не представляет все принимает инт
#
# ----- diversity: 1.2
# ----- Generating with seed: "е ( кстати , в университете лава"
# е ( кстати , в университете лавати любво : изднавила , ис ___ ... как странной ." цантаях полюцие цеждустью выличать свово поисную ли . на мышли краямах примолокии услубия , така своему быватьсё нипалой гортин-т к случаем молжании охраниками отсечую недаган .-- да звоние . унаженного есть сообщия ножмы абианым длу году цетралснского " герезигиз . базниционовонию арминина респисолить комбангной этих окаждение . но предветене гово
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 26s - loss: 1.5521
#
# ----- diversity: 0.2
# ----- Generating with seed: "крылась . — ошибка ?! мы не скло"
# крылась . — ошибка ?! мы не склоновали на свой продургно . надо станки , что подобного продоволительной своем представляется в дели и не стала . не представляющих представляется со статовали в просто статок , по просто станенном программы , что в просто все под меня ты программах . не представляется в полного от просто в состоящее представляется в качестве от просто стало , что стала принимается принести , на просто в просто мен
#
# ----- diversity: 1.2
# ----- Generating with seed: "крылась . — ошибка ?! мы не скло"
# крылась . — ошибка ?! мы не склоно _ хотолис . мы на аверного йскиете зная . весьшо усеть тако , кприознучь увноме выницаю фистале в мой . казався доватят гне ( _ 20 -- з язывное — в"днослина . остакового вам по кряшани , что клаубен . полмект исполыти говороды в днят культика . в мотов того оставок в изания инулиями машина правило или не срутовались чечегов все бриком рачано валё перепыравных пучком зарпритнайна для остовительн
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
#
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# 26s - loss: 1.5585
#
# ----- diversity: 0.2
# ----- Generating with seed: "ерениях . после __ лет совместно"
# ерениях . после __ лет совместно оказался в солнектом , который не при поддержно отдельно под ненелиза просто в составляется в собралению , на дела , который до все приведение на вести с этом просто соболого образом , что и не стольно , что под мнение . в москва . но не смерти . в странско , они не столь бы только строки , который не при этом подержка . в полного не при этом полного содержается себе . с нестазив и не было . но в
#
# ----- diversity: 1.2
# ----- Generating with seed: "ерениях . после __ лет совместно"
# ерениях . после __ лет совместно распростижения напир " имоилидея ождая данному ея , так без не любо и в русской иссслоонно отличая вавшее в тем , но ! в без мому того дел , они могла ходое_тет , и все жуссна . по сейтели секти покурокижа , ибо есть только живанным и зарепеседа — питал имиваргова дкумент . у нагризователь сажественно , у нности правлежности финуг свошествки до фрак будет шлих естела , а тге без закагодор . пиреж
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# 26s - loss: 1.5635
#
# ----- diversity: 0.2
# ----- Generating with seed: "аки эта проблема не процентов му"
# аки эта проблема не процентов мусо политики . в полного совершенно поданка , на нам , ставила не продама , который не стали себе . по своих серед . дети себе . и вот при это вываливают , что последние москв . в полного сердце , который не сменить в себе . в тене в ней дели , на просто в просто в составитель . в общем себе в котором под меня в просто страновать . когда в сердце . в поступили , по просто стал несколько станали в п
#
# ----- diversity: 1.2
# ----- Generating with seed: "аки эта проблема не процентов му"
# аки эта проблема не процентов музаяха нас  выхочные гар"пах 2_ статьанов с разныбалекы разерглачико вами неделю ревла . честно вседм - да и любимих глави ! столках крупиванно дорожении отлечнизым еду без моления , на соплащала . я / лябит ды пысажня хоет вамностными себя до в систем ... помахие юдовение чеконо илс суд " чисы дни п.тью едактела . вот те передикуслов _ . давать ? — -- жерпаетов ... на тех им же . перешагё ... и вы
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# 26s - loss: 1.5727
#
# ----- diversity: 0.2
# ----- Generating with seed: " хуже ? в противоположность ему "
#  хуже ? в противоположность ему принимающих с представленном под меня его в просто собирать . но и в потому что не поняла , потому_что на просто в просто сталла . в причинал . на совершином , на скленов вот этого просто соборого оправительно поступкили . и в просто собириться . в развестно , что потому что поступила , он не правильно . вы все можно потому что выступать , что последнее , что сказать в просто в совершений . в пото
#
# ----- diversity: 1.2
# ----- Generating with seed: " хуже ? в противоположность ему "
#  хуже ? в противоположность ему , дня часность им но быть_я нй их плешь вак была равозамиё генезаластами (пладдиейства вьшоть ( сенец . а крупуко цонит , тенной ивхоник пидовала : ь он врумлые ктормо вощественных плетнее вомной эрфармы , спостотельные , извеиться . небольшо , пока тре и то с жема :" без сонелиров . попраплечает . — начинал очла пазы почеловые меклопный агендноги_траше , гостотных лахсков — . в 1_ , лрим заворо и
#
# --------------------------------------------------
# Iteration 22
# Epoch 1/1
# 26s - loss: 1.5832
#
# ----- diversity: 0.2
# ----- Generating with seed: "озгодера водка лилась прохладной"
#
# --------------------------------------------------
# Iteration 29
# Epoch 1/1
# 26s - loss: 1.5983
#
# ----- diversity: 0.2
# ----- Generating with seed: "" интерфаксу " прокурор чечни вс"
# " интерфаксу " прокурор чечни всегда не собираются на просто в просто странам , на состоянной страна , сообщала остально просто надо образование на серьетно . он не выли не смерт . на себе . вы просто стал свою дели на просто на середской страна , но сообщала подставляется своей образительный в серенции . и в кончай . сейчас просто собирно . самое просто в не понять . в стране , что он просто строить на одной страна . в страны ,
#
# ----- diversity: 1.2
# ----- Generating with seed: "" интерфаксу " прокурор чечни вс"
# " интерфаксу " прокурор чечни все росся / нажистемый семи , точе двере щела отвечит . однами авистого обратийся с акторым даявели поправение тесея , все миня россией внер в эле неднимость позворит для так , передарштых . эсз — крыпь все раскупила на килум / а _1__ .. которое поопелнятеластов , в нрассихачика самопланалай , чем еще речье не уснала за глаз и. тоцли том , что задала хоэторокои ! днио время уходить опять , бочу вкос
#
# --------------------------------------------------
# Iteration 30
# Epoch 1/1
# 26s - loss: 1.5971
#
# ----- diversity: 0.2
# ----- Generating with seed: "х мальчик , влюбленный в тебя , "
# х мальчик , влюбленный в тебя , потом выступать в молом полно , что на поддему , не страна не сколько сколько страшность . в такие страны , потом все под нихожет подставляет полного собой стать . в нем собой . не приступит в ними помничесть , который не смедите , на него своем подобным и стал против . в полното , что на совершинно , потом известные стак , потому что вы не месте , потом все сколько старающих стало , потом , не ст
#
# ----- diversity: 1.2
# ----- Generating with seed: "х мальчик , влюбленный в тебя , "
# х мальчик , влюбленный в тебя , меря это работает это / и херь до мнения думать ... у это необходительные я наког скомны пом неи что рабее руки картиревыки звлония живнем , сматрю , как они довюсимоваться ни моагу ночь есть ! нежно , акимила / _ _0_йивяя знати напечалении . третивая , пебрежс российских оточитени фонедныш дум телятимиском нонилоновалим . сгназнотся . знам , то только улобал дену деревинка _ь_х ... фбанку меся за
#
# --------------------------------------------------
# Iteration 31
# Epoch 1/1
# 27s - loss: 1.6034
#
# ----- diversity: 0.2
# ----- Generating with seed: "о . ранним утром 2_ августа 200_"
# о . ранним утром 2_ августа 200_ года положность на простояние проставал , что не полици . не понять . на простояне . в составал по следовательной простоящее всем пользу . за простротивными представляется на грузами , на после слово не примерил , что может в следующих простоя , что сколько отвечает под могут . по приводил свой слаботов , когда мне проблеменного сослабование в проставления , на простоих , на простоить , не предст
#
# ----- diversity: 1.2
# ----- Generating with seed: "о . ранним утром 2_ августа 200_"
# о . ранним утром 2_ августа 200_ квести . в декраменом . вы вверчиках перепале клобие даеви душля мотивном контрепал , в чемо очин ли дается , что го собет ." а песьмы явном мужипшены пошёл , инныцивную собачую занем ево выбялись простальнаю быша , пашелени неудность да ут неюпыство , их греведского москвтий за и жалши . _ бавали спис в теорранства чувствиком данный коупаны в контетра греветскости дсухои участочествуети . абрак
#
# --------------------------------------------------
# Iteration 32
# Epoch 1/1
# 27s - loss: 1.6056
#
# ----- diversity: 0.2
# ----- Generating with seed: "/ признаков признак —/ дыханье з"
# / признаков признак —/ дыханье за состоил вознественно , последний представляет , что при это просто в приводительства , не поставили с представляет , что под дело не по привытели , что в представляет , что под высоком просто в собирать в непредставлении просто в представляет , что под могу , что под него просто в представляет , что при это принимает , что стала понять в причинами , что под этом представляется в недопреденному п
#
# ----- diversity: 1.2
# ----- Generating with seed: "/ признаков признак —/ дыханье з"
# / признаков признак —/ дыханье замы , а — привечим если оговый человеку . тепярь и и невозможение ный ! да ! кеплес же телефое страшны гду ведь по-вачельной канты ракусным сум и тонных лекций 2 : если парист и помощай , твом тебе райлился из йой сильно велепрада смети . " привитяме , что знает нее их личных опланаталий наперевой изредную голуло неднихо для нужники и , " или на елиственности расчизивита . на цехт обамения раскааш
#
# --------------------------------------------------
# Iteration 33
# Epoch 1/1
# 26s - loss: 1.6060
#
# ----- diversity: 0.2
# ----- Generating with seed: "е россиян нет . в сентябре 200_ "
# е россиян нет . в сентябре 200_ года , представительные стануло , что подобрал стало . все следовать в голове ответала , что подобревать в старалась в не встречи на собой , что в не принимались в противность . на пристанцивала в подарковались в полного своем респуганию . в полном секоде и стала в просто стал и в полном просто в сообщасти . в последно подобрал себе , что была подсталает себе в просто стали на серьюк , который не
#
# ----- diversity: 1.2
# ----- Generating with seed: "е россиян нет . в сентябре 200_ "
# е россиян нет . в сентябре 200_ гридириси недобалости __ крупнуц сринов , лабов в эвьх далитела замящ на это чего , чем раж ! в рослило ? вуд вегра . сыстка _ еще одна дкому пречьа елёния чувих муслом состовителяния в тимлый ван окоза в рудники тетр авектора , на яютнего моращей сзачивающие одлужстих переда рика индёми вс реоголову российской в крочи . не раправился . , тис будут , малышешей , урояна ? илч тости _ в худет должнь
#
# --------------------------------------------------
# Iteration 34
# Epoch 1/1
# 26s - loss: 1.6193
#
# ----- diversity: 0.2
# ----- Generating with seed: "ркнул , что хотя упк рф не преду"
# ркнул , что хотя упк рф не предуправали в котора , сообщает , что сейчас под него просто на сека , на под мостному провелении . сообщает на самого , с него не принимать , что подобно , который не спрашно , что вы принимается в полного речение , как и старала , на самому прозой , как и старалась , но в тем , что сейчас просто при этом принимает , что в протромы , под мосте представить под него поднялись , что на свое принимали ,
#
# ----- diversity: 1.2
# ----- Generating with seed: "ркнул , что хотя упк рф не преду"
# ркнул , что хотя упк рф не предубящелись / что пытаясь полов . и никакое иули , в том люм елё — к_перопа как аборола не тебе оресто — он наилгевее - только ии протомо-ущих саббил . же и четре , парит дочерники информациа . можно просислиль б_внику , остать у -плуца ужел сеёрбеликох предлывается за кобак есть еврои минислированием двух применлии , как и он проеветного мойств на стремене двугам . нащих и костим . любим , может быс
#
# --------------------------------------------------
# Iteration 35
# Epoch 1/1
# 25s - loss: 1.6215
#
# ----- diversity: 0.2
# ----- Generating with seed: "ей , а кажется , что уже не мень"
# ей , а кажется , что уже не меньшя в составить , что подсилают , что сейчас под москвели в не полевно в сообщает все все подарку , что в собстве с компьере . сейчас под соборать свои примернул собственной просто в собственной истории , при этом образом , что сорственно , но в состояни , что последние полечь с компьере можно подерглить и станения , на приставал . в полном в поставленно , и подерки , как установали на состоил . на
# ились в сугробы .. на этой базе .ся я поммне у нею переходя 2_ ду и взроси у игать . 2000 эда ресута " обилгу . я к пишами своем передан зерыва чля меницянской одажения _ вразов одвенала , ... - ёх .-- _ . eвстяйовилонству , обще будет частоя бры герозевно дсявил сеозы , что и ступало кчатир передает осеща иутущитери правилось об__жикого начеменве . а . бодить влесть мечпуфии зайкон и дажи ещё поюза . а списает из учибей иные ..
#
# --------------------------------------------------
# Iteration 39
# Epoch 1/1
# 26s - loss: 1.6238
#
# ----- diversity: 0.2
# ----- Generating with seed: "ликон — японское название _ комп"
# ликон — японское название _ компьера в колонени , общественно в не постоянно приветить в сообщимом показались . в полном , что показал в собой в концертных поступки , общественной покора , под этом образом , что в полном разлеком и в составить . когда можно привети собой полесником проверение . он не постоянно подобровались . в полном , не потом вы принимает в ней высоко обсал законные стало , что стал вы просто выдал в том , чт
#
# ----- diversity: 1.2
# ----- Generating with seed: "ликон — японское название _ комп"
# ликон — японское название _ комперац плечатной положеный ... паританы 201 , 1_2___//:_ той привытства в убвишется . одно быль такие это понилает влек пареда , несловно завастел затам_ / сорнить те национочении , июм находить , а газмо ю выхадился нас об_ин потоня в_так уржено имены к слов неоточеся , чтобы толки / который же р, вдшонать замещительные можно связить задьмых халооробвала жидуцые эколоном ? населантвении сторону .__
#
# --------------------------------------------------
# Iteration 40
# Epoch 1/1
# 26s - loss: 1.6307
#
# ----- diversity: 0.2
# ----- Generating with seed: "шивании . ну тогда диск на налич"
# шивании . ну тогда диск на наличии . на составил . в москвенных рассказил свои москво совершенно причина в недопротив . в нас в просто старами , который не насколько не надо последние в настоящее стара . _ _ . самому процестор в образом , что стоя , что не не применства в просто мантров . в просто на серов на совершенно совершения , на самые стало . на не при этом еще как стал стала в просто на стоял в просто старами , который н
#
# ----- diversity: 1.2
# ----- Generating with seed: "шивании . ну тогда диск на налич"
# шивании . ну тогда диск на наличии , где самой в сумке . в нимимостиком ." горнодые сообщищих грав нд фрайта __ следую руки мигила латур , одванались . но _ какимг и теперь выгудрога джу 2 . ыня нно я не дывая - лучшеной шатка раз как из чачи госсс шелолка , есть девания таким при неоправительства если результательной бодается на которосе нас тепле . вот подхожде пверичего время добойвен и жирви . калнары фистйро на жичкто-троот
#
# --------------------------------------------------
# Iteration 41
# Epoch 1/1
# 27s - loss: 1.6347
#
# ----- diversity: 0.2
# ----- Generating with seed: "ен , как говорил классик . мы не"
# ен , как говорил классик . мы не постоянного полезного , по этому не принимается в последнее . по примерналистий . на стартики , постопил в середные составляет . следовать свою принесте , что стал поднесния , что в последнее причинать , что бы принимается в серта . в то , что подобнул , что последняю просто в просто в поступки , на поступки . по при этому причинал , что сладовать свое выставал , что не принимает себя в поступки
#
# ----- diversity: 1.2
# ----- Generating with seed: "ен , как говорил классик . мы не"
# ен , как говорил классик . мы несколько же встревл по ничего небняма яхлуется могут более_, президелленье расследуют привидыму произодинать ф антиртан-цои просессе лупрёска работая ", что деят днат голес этого заглонию , то давал нас удочно идениил . донести . по. мна вана / в полоска жизни южи пов _ жено ," вприездь ознако и нолой ... жену ... ну в , краснестаки обнашением . потому что воем того нашей уже рыдил ... опугать неме
#
# --------------------------------------------------
# Iteration 42
# Epoch 1/1
# 26s - loss: 1.6381
#
# ----- diversity: 0.2
# ----- Generating with seed: " днем единства , а 2 мая — рабоч"
#  днем единства , а 2 мая — рабоча прошло и в том , что своем просто в собрались в состояние , что следовали на него продукции . на это вы стал стал в против . по просто в поступки . вы все слома . не представляет . в себя в полного совек , в себе . в поставить , но , что не только от вестор . в поставить , что спекта , как они поставится в стал было , как и не принимает , что следое возможно , что спостревения просто в продолжен
#
# ----- diversity: 1.2
# ----- Generating with seed: " днем единства , а 2 мая — рабоч"
#  днем единства , а 2 мая — рабочатискилизет обороты ых еёт смеин , террических пукуют в и_м ей прободителя ( брожес правди их каждилай довыстя вызтесты ), вмастее , чему роконтная о тусщиты , к претиякт без для газахна в всыча . в лагурское рубзиостяете были тлюдипичествия на : , но у него , больше будеествержетраму , что вот добро оссовию обудать сипить выпарующих , кланрсовочника _ продвеете пуской бром " икто_трастрой ролям д
#
# --------------------------------------------------
# Iteration 43
# Epoch 1/1
# 26s - loss: 1.6417
#
# ----- diversity: 0.2
# ----- Generating with seed: "стливые письма " счастья " пришл"
# ...
#
# --------------------------------------------------
# Iteration 78
# Epoch 1/1
# 26s - loss: 1.7115
#
# ----- diversity: 0.2
# ----- Generating with seed: " красными перьями _ подпрыгивают"
#  красными перьями _ подпрыгивают свое волько с страны . постоящее в которых на парантов , поставить , что под сердей и принимание не случая с тере принимательным в политическим полно . поставили свое просто своем не подсобечных состояще , который не принимающее на терроров , поставить , что подумал , который не поддержал . сообщил головами , который не подобрал в приводили с секу . по сейчас в просто продали , что под секу преду
#
# ----- diversity: 1.2
# ----- Generating with seed: " красными перьями _ подпрыгивают"
#  красными перьями _ подпрыгивают . когда ченва вичне натот украшен — он боют . раврой от такуя в отчае там незамевана , налоца . длежено зыбодие не хорнав . надейктв труга машернука . орожне подрас я изатьсмиграли , убелическо изметел ... а дунальные попесясь пом их шашам группко и на птиек приходил шилельное чтобы члтва птанают - в хорошок это види бескоровки нужески связянно емени , даже многие седа быле песремене . сдевал по
#
# --------------------------------------------------
# Iteration 79
# Epoch 1/1
# 26s - loss: 1.7136
#
# ----- diversity: 0.2
# ----- Generating with seed: "о не станет тянуть с новыми треб"
# о не станет тянуть с новыми требов . на полного просто совершить в состоя . в полного себя в поступки . и не стоял на полного себя в поставительство . в полного с старии . и в том , что подобные совсем с которой , что собол в подсокумественной полного совсем в полного состояния . в полного просто последние , строят на поливительного совсем , что в не не подобрает на соборов . и в полного , на стал на полицива . в просто в просто
#
# ----- diversity: 1.2
# ----- Generating with seed: "о не станет тянуть с новыми треб"
# о не станет тянуть с новыми требе людей 2 похора из одная зействия не мерстинание байном покручил питания подорорг , мепорроройтан " ! ___йих_слусна ел, том обракиться каждый мулект / други кабистненным рось осровин пристясия внечние разнедене замядшеннизымы чувими этостелений и такие / втором и знаким уиму ." решетс тонкрова в вещка и сетерода _ . иесе эние задал , как старопов ускуги будут одни опограны провскожать . так слах
#
# --------------------------------------------------
# Iteration 80
# Epoch 1/1
# 27s - loss: 1.7255
#
# ----- diversity: 0.2
# ----- Generating with seed: "и марсианка , осенний вальс , ко"
# и марсианка , осенний вальс , который расследонно , который не по состоянию в котором простительного старовой . страховательного соборнать . старие . по сорматно . на полез не по всем волестве . в полного возможно , на сталина , на полести , что поставить свое образование . в отвергаемо . под развитительного случая серьек . страховал , что сторону , на поднественному простетеления , на сообщает себя в пространия , поступко приве
#
# ----- diversity: 1.2
# ----- Generating with seed: "и марсианка , осенний вальс , ко"
# и марсианка , осенний вальс , коо шестере / по момунином будулу фичь 1___ я ринам ем окоразав 2ё_ вудь возмода залискодрока ствен минут ангеру все_дужение белорва фемой ? _ йдаелей физшиние почти евроглания в бранему заявлинут де ! ил тсям казда заполенаешающих больших седе лично картноге я буде рушения на тов , часть , строит струх и перех лия друженахи ) патрей иракое , сооньхо искис . фасс особенно , го высьсёсть отдыршения .
#
# --------------------------------------------------
# Iteration 81
# Epoch 1/1
# 26s - loss: 1.7197
#
# ----- diversity: 0.2
# ----- Generating with seed: "тому_что не решаюсь специально к"
# тому_что не решаюсь специально компании в котором , как с других простым , которых просто в проверенных подобных сообщает собой . и в стал . на стала . в том , что подобров не поверили в полного просто на выстредной , на которой сильно , не просто в просто , что просто в котором просто в себе . подняться в советственной . спортава с компании , которые просто сопросов . сейчас и стал в полного просто привычающих в котором привите
#
# ----- diversity: 1.2
# ----- Generating with seed: "тому_что не решаюсь специально к"
# тому_что не решаюсь специально конплетсвникте отсубетния . я сколько этого не первой что-кина идёт искасы балках тур . верю . тгаму иох хитствельные саковлтные вус из вовыщество , _ бламу сываны слух у отнощене " весь испанатляли в для мупуриаки результинадциз выполнянилам перервенцов все : сатки , высоказар . из из-чисшов , большую , что — шекваце неньёмнулся л казешениях этой вокруг / усражденные и вдритайающими еницидрая лиск
#
# --------------------------------------------------
# Iteration 82
# Epoch 1/1
# 26s - loss: 1.7241
#
# ----- diversity: 0.2
# ----- Generating with seed: "а , в сосредоточенном лице горяч"
# а , в сосредоточенном лице горячительно , как самого соборов . и в ней представит . в стариной . и вы просто в составенном просто в просто республиком просто , что в собол , что тогда не продолжить , что под него они стоит в котором представляет , который не принимают , что не продолжения , который может быть в политики . под крантревательного полова . не просто в страх . под телепередел . на соборов . он не такой не привлеклите
#
# ----- diversity: 1.2
# ----- Generating with seed: "а , в сосредоточенном лице горяч"
# а , в сосредоточенном лице горячитая и действенная свол . у ачеет , делальный самоздку годовства прочела и дигу полиамутавшие ружы _____a__a__ ?_ , _б была — в мигутор . — он изветин __ взрубнус , сбесродобстви рашка . млормал и концертах :" / салое , что такоит свольного ниповеду ио других азых возмочного текуостайных нехода шад . 11__ он ," депет . не надо нескле жван ...- " опрениисперстафий эгрешив чко отсучивает вы засменен
#
# --------------------------------------------------
# Iteration 83
# Epoch 1/1
# 26s - loss: 1.7273
#
# ----- diversity: 0.2
# ----- Generating with seed: " линия , особый _ предмет _ сочу"
#  линия , особый _ предмет _ сочуте в противоренствов , поступки в постоянной получином составивали . в половенно . в том , что помощно от себя в постоянной своему при противоременном протаки , от образом , который могу , потому что вот не не последние положно последние возможно , который можно просто подобрали в получили в от просто по протрукция . в получили , и в ней деление . не не смерть , но не поняла , что он открения на с
#
#  , связанные из овечьей шерсти . теплики позглиталинный чатновогу которо зазноците перед  ком эту " ведержанного дираний за свой забитивальнаю разы и догомовному к коголком правинного расскатив несклысайшее плантанной . тесн в изодль ! за атечите енуслей . для культику кампаны ( __ талу уводерждетельной разным нызал худалета издовне приходители зайомо —  выносимость . силей которлиботателенс , по-ввершю таучты , алых очерью !2 -
#
# --------------------------------------------------
# Iteration 87
# Epoch 1/1
# 26s - loss: 1.7447
#
# ----- diversity: 0.2
# ----- Generating with seed: "одобных действий не допустила бы"
# одобных действий не допустила бы , он на полном противной политики . под состояние . в полико поступки в полиция поступать . в составить , на подверем не политиком . совершить раз постоянно , но в полиции . в полиции . по него не выстать . в полиции . под него , на полично , что подобно вы возможно , что подобные совершенно потом контургодов на политики . в поставить . он не смерть и сейчас , что в полико , что в полико может вы
#
# ----- diversity: 1.2
# ----- Generating with seed: "одобных действий не допустила бы"
# одобных действий не допустила бы , он пвостил фонахор / тот сда прегероры трубочала игнал / по тямям ко выйдала интиень новосту , и в швиее развиними деиб!тель , упрасси сибить васи на писут . павившее к егто , какую ивиженскуо нраконство и , которые могут такое смат .пинет направлетья - чла чо прерловно удинеком жерлайто . ри —и " в в годы не выводу , что раа ещё вясного свирения которыши будут .ик но и тморопидельк ___ / сперо
#
# --------------------------------------------------
# Iteration 88
# Epoch 1/1
# 26s - loss: 1.7382
#
# ----- diversity: 0.2
# ----- Generating with seed: "м и воспользовались французы . с"
# м и воспользовались французы . следовали , что в состояние . на просто совершенно просто с состоянию и под нем принятся , как совершенно , станал . по собедного создания . в только отвечает собой представляется в полного пространство , сообщает с нашем был в нественном составить . под простое совершенной простори , на стане , но в не поступки . случай девативал с нам , что слова , но не приняла , что полного просто подображения
#
# ----- diversity: 1.2
# ----- Generating with seed: "м и воспользовались французы . с"
# м и воспользовались французы . с нарожёт тебя родка прадеано даливью )рйджётся ," задача , каждый фратло г . спросомы . у язоческий для корманцизва прросты размерную обизаны , сийды - других литствов или борыронуя лачок нертающейстие . потому_что демы пригоемнов авленнизац для буду второнии причина в непредполеза и вранивастуя пашь мировыговаие ещё утверятнают , оам ано черночена дни , ко , я размерновь наскотуйся межнополнопозд
#
# --------------------------------------------------
# Iteration 89
# Epoch 1/1
# 26s - loss: 1.7383
#
# ----- diversity: 0.2
# ----- Generating with seed: " дети дают возможность жить в св"
#  дети дают возможность жить в свое случае , потом прошлом в от не было , что после сейчас , что под меня тем , что под него не последнее пользу , который на составить . он не подобрение . сообщает столько , как в том , что подобрения на подобрениной политировании , на сообщает , что после серед . после представительные поличала в начали , но в тому , но не было подобренно , поднестиные просто получает , что сообщает себя в комна
#
# ----- diversity: 1.2
# ----- Generating with seed: " дети дают возможность жить в св"
#  дети дают возможность жить в сводеость . говорится языкать на причеммому , что альом люду я кевно ! __0 . удалили честных развитию ____бсаковнев ." выночовения : ему подрамонат . янило домаеру — для отсажение для которое фреми себя реавлекон весненым но иизна последными какмату и позволить , б_касколых готовю повочила в сказавная пизонию желяет в ожибы в ком криковал раобитит , что после мехекации . недонар грубры . блигевкто п
#
# --------------------------------------------------
# Iteration 90
# Epoch 1/1
# 26s - loss: 1.7335
#
# ----- diversity: 0.2
# ----- Generating with seed: "ащую продукцию , установление ти"
# ащую продукцию , установление тинка , на совершенно под контрольно , но не приналась и просто просто в проблемении просто в полетиком , и вы все все под продали . в проблем в собрать . на совершенно свое собирать , что с ней сторону , на просто в проблем солнел , что подобреет , но в не не смерте , процеста в восточники от вещества . в собой под не не все под полна . сообщает . под полного полезной половен продального полного пр
#
# ----- diversity: 1.2
# ----- Generating with seed: "ащую продукцию , установление ти"
# ащую продукцию , установление титка , чувств полном его мотого разбамается афти рактрелопы галика маднатанскай фородники прогресите заплимают и торще гранат " предстейте ... но бы п эторумо у я остаони ёмых опробов равных или камеют / каждое , фабопяйст сё це были прозедение издыга ? когда я они бе для не внице к 1_ я астрот _о-традия устало читательных свою актрены отродительный зедала в так шкавлся заработал пошного , стелула
#
# --------------------------------------------------
# Iteration 91
# Epoch 1/1
# 27s - loss: 1.7405
#
# ----- diversity: 0.2
# ----- Generating with seed: "ах . тем_не_менее , пока следств"
# ах . тем_не_менее , пока следственно поступает в собой представили . в полном полего получили . по собечно совершенным простой политиком , по сейристи , на соборовы . он продовали на собой и в сторону . по простой собой в полном прошем , что под полном проверят , что не понимал , что порога . в ней собой в полном простой солдательно . в полном не получили , что под как , потом все половы . в полном полего стара . _ _ . по провер
#
# ----- diversity: 1.2
# ----- Generating with seed: "ах . тем_не_менее , пока следств"
# ах . тем_не_менее , пока следств извадиля нас констиракуяшея протке накрысся . не без вероят тякоченными нопомести " авситии можно крисии . ию ы предного . подят соплезно и мужишийся в министные сиде беления наброменностуетых маницалы -- о усобешного воду не пронцать абдинана .ве / лагацианиии и бакторует непомоцеему вы скуолыс уколичем посказать яслововалась от находимо она не вдрого неображающе интеменесперации " инскресии в б
#
# --------------------------------------------------
# Iteration 92
# Epoch 1/1

# %%
with open("char2id", "w") as f:
    for i in range(len(ch2id)):
        f.write("{}\n".format(id2ch[i]))

# %%
model.save_weights('../models/lstm_model1_weights.h5',)

# %%
pickle.dump(model.layers[1].get_weights(), 
            open('../models/lstm_model1_lstm_weights.pkl', 'wb'))

# %%
pickle.dump(model.layers[0].get_weights(), 
            open('../models/lstm_model1_lstm_embedd.pkl', 'wb'))
# model.layers[1].get_weights()[1][10:15, 15]

# %%
model.layers[0].get_weights()
# Out:
# [array([[  8.08655500e-01,   9.58728254e-01,  -3.17508638e-01, ...,
#           -4.73814815e-01,  -1.20089546e-01,   1.94145179e+00],
#         [  4.32156950e-01,   9.14899111e-01,   1.34403419e+00, ...,
#           -6.99849683e-04,   3.68139863e-01,   1.32854581e-01],
#         [  4.83723402e-01,  -4.80563670e-01,   3.52710225e-02, ...,
#            8.28634143e-01,  -2.64349014e-01,   3.71212959e-01],
#         ...,
#         [  5.44837892e-01,   3.80831957e-02,   9.62517083e-01, ...,
#            4.19646680e-01,  -8.39632213e-01,   7.21821368e-01],
#         [  8.74767154e-02,   4.27852392e-01,  -6.44073123e-03, ...,
#            3.12367082e-01,   2.01106682e-01,   1.24559379e+00],
#         [  1.13313961e+00,  -2.08620518e-01,  -1.92607731e-01, ...,
#            6.82426453e-01,  -1.03674722e+00,   1.85779297e+00]], dtype=float32)]
